# %% [markdown]
# <a href="https://colab.research.google.com/github/spshreya/dataAnalytics/blob/main/EDA_StudentPerformance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA with Seaborn, NumPy and Pandas

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-43637085-7dff-4fe1-a3a8-e68c265807ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-43637085-7dff-4fe1-a3a8-e68c265807ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving StudentsPerformance.csv to StudentsPerformance (1).csv

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head
# Out:
# <bound method NDFrame.head of      gender race/ethnicity  ... reading score writing score
# 0    female        group B  ...            72            74
# 1    female        group C  ...            90            88
# 2    female        group B  ...            95            93
# 3      male        group A  ...            57            44
# 4      male        group C  ...            78            75
# ..      ...            ...  ...           ...           ...
# 995  female        group E  ...            99            95
# 996    male        group C  ...            55            55
# 997  female        group C  ...            71            65
# 998  female        group D  ...            78            77
# 999  female        group D  ...            86            86
#
# [1000 rows x 8 columns]>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df['parental level of education'].unique()
# Out:
# array(["bachelor's degree", 'some college', "master's degree",
#        "associate's degree", 'high school', 'some high school'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
corMat = df.corr()
corMat
# Out:
#                math score  reading score  writing score
# math score       1.000000       0.817580       0.802642
# reading score    0.817580       1.000000       0.954598
# writing score    0.802642       0.954598       1.000000

# %%
sns.heatmap(corMat, annot=True)

# %%
sns.pairplot(df)

# %%
sns.relplot(x='math score', y='reading score', hue='gender', data=df)  #seeing relation

# %%
sns.relplot(x='math score', y='reading score', hue='test preparation course', data=df)  #idt there is any relation

# %%
sns.relplot(x='reading score', y='writing score', hue='test preparation course', data=df)   #can see something

# %%
sns.relplot(x='math score', y='reading score', hue='parental level of education', data=df)   #can drop

# %%
sns.relplot(x='math score', y='reading score', hue='lunch', data=df)  #can see something

# %%
sns.displot(df['math score'])

# %%
sns.distplot(df['reading score'], bins=20)
#FutureWarning: `distplot` is a deprecated function and will be removed in a future version. 
#Please adapt your code to use either `displot` (a figure-level function with similar flexibility) 
#or `histplot` (an axes-level function for histograms)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.displot(df['reading score'])   #just looking at the future warning

# %%
sns.histplot(df['reading score'])    #just looking at the future warning

# %%
sns.catplot(x='math score', kind='box',data=df)              #outliers

# %%
sns.catplot(x='writing score', kind='box',data=df)

# %%
sns.catplot(x='reading score', kind='box',data=df)
